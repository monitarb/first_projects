# %%
def get_pages():
    pages=[]
    page='https://www.wunderground.com/history/airport/SKAR/{}/{}/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211'
          https://www.wunderground.com/history/airport/SKAR/%7B%7D/%7B%7D/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211
    months=range(1,13)
    years=range(2009,2018)

    for year in years :
        for month in months :
            pages.append(page.format(year,month))
            
    return res
href="/history/airport/SKAR/2010/2/10/MonthlyHistory.html
	# ?req_city=El Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211"
get_pages()
# Out:
# ['https://www.wunderground.com/history/airport/SKAR/2009/1/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211',
#  'https://www.wunderground.com/history/airport/SKAR/2009/2/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211',
#  'https://www.wunderground.com/history/airport/SKAR/2009/3/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211',
#  'https://www.wunderground.com/history/airport/SKAR/2009/4/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211',
#  'https://www.wunderground.com/history/airport/SKAR/2009/5/10/MonthlyHistory.html?req_city=El%20Eden&req_state=QUI&req_statename=Colombia&reqdb.zip=00000&reqdb.magic=476&reqdb.wmo=80211',
# ...

# %%
response.xpath('//table[@id="historyTable"]/tbody/tr/td/span/span[@class="wx-value"]/text()').extract()
Temp. Avg: [4]
Dew Point[10]
Precip. Avg[13] (Muchos ceros?)
Precip. Sum[15]
Wind Avg[17]

Humedad(lista y promedio)
response.xpath('//table[@id="obsTable"]/tbody/tr/td/span[@class="wx-value"]/text()').extract()
Empezar en 7 e ir saltando de a 18

Proxima pagina: //div[@class="next-link"]/a/@href
# Out:
#   File "<ipython-input-14-36eaec4fe78b>", line 3
#     Dew Point[10]
#             ^
# SyntaxError: invalid syntax

# %%
x=[1,5,3,67,9,6,43,45,8,90,7,3,2,6,8,90,3,6,8,3,1,2,7,0,9,8,5,6,4,28]

#[x[7+18*i] for i in range(0,30)]
[7+18*i for i in range(0,30)]
# Out:
# [7,
#  25,
#  43,
#  61,
#  79,
#  97,
#  115,
#  133,
#  151,
#  169,
#  187,
#  205,
#  223,
#  241,
#  259,
#  277,
#  295,
#  313,
#  331,
#  349,
#  367,
#  385,
#  403,
#  421,
#  439,
#  457,
#  475,
#  493,
#  511,
#  529]

# %%
#response.xpath('//table[@id="obsTable"]/tbody/tr/td').extract()
total_list=['<td>Jan</td>',
 '<td class="daily-td-grey">high</td>',
 '<td class="daily-td-grey">avg</td>',
 '<td class="daily-td-grey">low</td>',
 '<td class="daily-td-white">high</td>',
 '<td class="daily-td-white">avg</td>',
 '<td class="daily-td-white">low</td>',
 '<td class="daily-td-grey">high</td>',
 '<td class="daily-td-grey">avg</td>',
 '<td class="daily-td-grey">low</td>',
 '<td class="daily-td-white">high</td>',
 '<td class="daily-td-white">avg</td>',
 '<td class="daily-td-white">low</td>',
 '<td class="daily-td-grey">high</td>',
 '<td class="daily-td-grey">avg</td>',
 '<td class="daily-td-grey">low</td>',
 '<td class="daily-td-white">high</td>',
 '<td class="daily-td-white">avg</td>',
 '<td class="daily-td-white">high</td>',
 '<td class="daily-td-grey">sum</td>',
 '<td class="b" style="background-color: #FFF;">\xa0</td>',
 '<td><a href="/history/airport/SKAR/2017/1/1/DailyHistory.html">1</a></td>',
 '<td>\n  <span class="wx-value">82</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">77</span>\n</td>',
 '<td>\n  <span class="wx-value">51</span>\n</td>',
 '<td>\n  <span class="wx-value">30.08</span>\n</td>',
 '<td>\n  <span class="wx-value">30.02</span>\n</td>',
 '<td>\n  <span class="wx-value">29.95</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\nFog\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/2/DailyHistory.html">2</a></td>',
 '<td>\n  <span class="wx-value">85</span>\n</td>',
 '<td>\n  <span class="wx-value">74</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">73</span>\n</td>',
 '<td>\n  <span class="wx-value">48</span>\n</td>',
 '<td>\n  <span class="wx-value">30.10</span>\n</td>',
 '<td>\n  <span class="wx-value">30.01</span>\n</td>',
 '<td>\n  <span class="wx-value">29.92</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\n\t\xa0\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/3/DailyHistory.html">3</a></td>',
 '<td>\n  <span class="wx-value">84</span>\n</td>',
 '<td>\n  <span class="wx-value">73</span>\n</td>',
 '<td>\n  <span class="wx-value">62</span>\n</td>',
 '<td>\n  <span class="wx-value">67</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">94</span>\n</td>',
 '<td>\n  <span class="wx-value">77</span>\n</td>',
 '<td>\n  <span class="wx-value">50</span>\n</td>',
 '<td>\n  <span class="wx-value">30.04</span>\n</td>',
 '<td>\n  <span class="wx-value">29.98</span>\n</td>',
 '<td>\n  <span class="wx-value">29.89</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.08</span>\n</td>',
 '<td>\nFog\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/4/DailyHistory.html">4</a></td>',
 '<td>\n  <span class="wx-value">76</span>\n</td>',
 '<td>\n  <span class="wx-value">70</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">88</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">30.07</span>\n</td>',
 '<td>\n  <span class="wx-value">29.99</span>\n</td>',
 '<td>\n  <span class="wx-value">29.92</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">3</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.43</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/5/DailyHistory.html">5</a></td>',
 '<td>\n  <span class="wx-value">77</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">60</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">89</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">30.07</span>\n</td>',
 '<td>\n  <span class="wx-value">30.01</span>\n</td>',
 '<td>\n  <span class="wx-value">29.96</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.55</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n\t,\nThunderstorm\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/6/DailyHistory.html">6</a></td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">70</span>\n</td>',
 '<td>\n  <span class="wx-value">60</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">76</span>\n</td>',
 '<td>\n  <span class="wx-value">52</span>\n</td>',
 '<td>\n  <span class="wx-value">30.06</span>\n</td>',
 '<td>\n  <span class="wx-value">30.01</span>\n</td>',
 '<td>\n  <span class="wx-value">29.92</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">4</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\nFog\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/7/DailyHistory.html">7</a></td>',
 '<td>\n  <span class="wx-value">84</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">62</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">77</span>\n</td>',
 '<td>\n  <span class="wx-value">43</span>\n</td>',
 '<td>\n  <span class="wx-value">30.12</span>\n</td>',
 '<td>\n  <span class="wx-value">30.04</span>\n</td>',
 '<td>\n  <span class="wx-value">29.93</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.01</span>\n</td>',
 '<td>\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/8/DailyHistory.html">8</a></td>',
 '<td>\n  <span class="wx-value">73</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">89</span>\n</td>',
 '<td>\n  <span class="wx-value">73</span>\n</td>',
 '<td>\n  <span class="wx-value">30.14</span>\n</td>',
 '<td>\n  <span class="wx-value">30.09</span>\n</td>',
 '<td>\n  <span class="wx-value">30.02</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">3</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.04</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/9/DailyHistory.html">9</a></td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">58</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">59</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">85</span>\n</td>',
 '<td>\n  <span class="wx-value">52</span>\n</td>',
 '<td>\n  <span class="wx-value">30.13</span>\n</td>',
 '<td>\n  <span class="wx-value">30.05</span>\n</td>',
 '<td>\n  <span class="wx-value">29.96</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">3</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.12</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/10/DailyHistory.html">10</a></td>',
 '<td>\n  <span class="wx-value">78</span>\n</td>',
 '<td>\n  <span class="wx-value">70</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">85</span>\n</td>',
 '<td>\n  <span class="wx-value">61</span>\n</td>',
 '<td>\n  <span class="wx-value">30.07</span>\n</td>',
 '<td>\n  <span class="wx-value">29.99</span>\n</td>',
 '<td>\n  <span class="wx-value">29.92</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">0</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/11/DailyHistory.html">11</a></td>',
 '<td>\n  <span class="wx-value">80</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">84</span>\n</td>',
 '<td>\n  <span class="wx-value">58</span>\n</td>',
 '<td>\n  <span class="wx-value">30.08</span>\n</td>',
 '<td>\n  <span class="wx-value">30.00</span>\n</td>',
 '<td>\n  <span class="wx-value">29.91</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.39</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/12/DailyHistory.html">12</a></td>',
 '<td>\n  <span class="wx-value">82</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">76</span>\n</td>',
 '<td>\n  <span class="wx-value">45</span>\n</td>',
 '<td>\n  <span class="wx-value">30.09</span>\n</td>',
 '<td>\n  <span class="wx-value">30.01</span>\n</td>',
 '<td>\n  <span class="wx-value">29.94</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">5</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\n\t\xa0\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/13/DailyHistory.html">13</a></td>',
 '<td>\n  <span class="wx-value">83</span>\n</td>',
 '<td>\n  <span class="wx-value">74</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">47</span>\n</td>',
 '<td>\n  <span class="wx-value">30.09</span>\n</td>',
 '<td>\n  <span class="wx-value">30.02</span>\n</td>',
 '<td>\n  <span class="wx-value">29.93</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">4</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.02</span>\n</td>',
 '<td>\nFog\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/14/DailyHistory.html">14</a></td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">86</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">30.10</span>\n</td>',
 '<td>\n  <span class="wx-value">30.02</span>\n</td>',
 '<td>\n  <span class="wx-value">29.94</span>\n</td>',
 '<td>\n  <span class="wx-value">9</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  <span class="wx-value">8</span>\n</td>',
 '<td>\n  <span class="wx-value">2</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\nFog\n\t,\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/15/DailyHistory.html">15</a></td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">81</span>\n</td>',
 '<td>\n  <span class="wx-value">58</span>\n</td>',
 '<td>\n  <span class="wx-value">30.07</span>\n</td>',
 '<td>\n  <span class="wx-value">30.00</span>\n</td>',
 '<td>\n  <span class="wx-value">29.91</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">6</span>\n</td>',
 '<td>\n  <span class="wx-value
n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/30/DailyHistory.html">30</a></td>',
 '<td>\n  <span class="wx-value">82</span>\n</td>',
 '<td>\n  <span class="wx-value">73</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">68</span>\n</td>',
 '<td>\n  <span class="wx-value">66</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">82</span>\n</td>',
 '<td>\n  <span class="wx-value">52</span>\n</td>',
 '<td>\n  <span class="wx-value">30.11</span>\n</td>',
 '<td>\n  <span class="wx-value">30.05</span>\n</td>',
 '<td>\n  <span class="wx-value">29.93</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">3</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.02</span>\n</td>',
 '<td>\nRain\n</td>',
 '<td><a href="/history/airport/SKAR/2017/1/31/DailyHistory.html">31</a></td>',
 '<td>\n  <span class="wx-value">80</span>\n</td>',
 '<td>\n  <span class="wx-value">72</span>\n</td>',
 '<td>\n  <span class="wx-value">63</span>\n</td>',
 '<td>\n  <span class="wx-value">67</span>\n</td>',
 '<td>\n  <span class="wx-value">65</span>\n</td>',
 '<td>\n  <span class="wx-value">64</span>\n</td>',
 '<td>\n  <span class="wx-value">100</span>\n</td>',
 '<td>\n  <span class="wx-value">79</span>\n</td>',
 '<td>\n  <span class="wx-value">57</span>\n</td>',
 '<td>\n  <span class="wx-value">30.12</span>\n</td>',
 '<td>\n  <span class="wx-value">30.05</span>\n</td>',
 '<td>\n  <span class="wx-value">29.95</span>\n</td>',
 '<td>\n  <span class="wx-value">12</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">3</span>\n</td>',
 '<td>\n  <span class="wx-value">7</span>\n</td>',
 '<td>\n  <span class="wx-value">1</span>\n</td>',
 '<td>\n  -\n</td>',
 '<td>\n  <span class="wx-value">0.00</span>\n</td>',
 '<td>\nThunderstorm\n</td>']

# %%
len(total_list)
# Out:
# 672

# %%
#total_list[29] y cada 21 (50, 71)
raw_list=[total_list[29+21*i] for i in range(0,31)]
raw_list
# Out:
# ['<td>\n  <span class="wx-value">77</span>\n</td>',
#  '<td>\n  <span class="wx-value">73</span>\n</td>',
#  '<td>\n  <span class="wx-value">77</span>\n</td>',
#  '<td>\n  <span class="wx-value">88</span>\n</td>',
#  '<td>\n  <span class="wx-value">89</span>\n</td>',
#  '<td>\n  <span class="wx-value">76</span>\n</td>',
#  '<td>\n  <span class="wx-value">77</span>\n</td>',
#  '<td>\n  <span class="wx-value">89</span>\n</td>',
#  '<td>\n  <span class="wx-value">85</span>\n</td>',
#  '<td>\n  <span class="wx-value">85</span>\n</td>',
#  '<td>\n  <span class="wx-value">84</span>\n</td>',
#  '<td>\n  <span class="wx-value">76</span>\n</td>',
#  '<td>\n  <span class="wx-value">79</span>\n</td>',
#  '<td>\n  <span class="wx-value">86</span>\n</td>',
#  '<td>\n  <span class="wx-value">81</span>\n</td>',
#  '<td>\n  <span class="wx-value">70</span>\n</td>',
#  '<td>\n  <span class="wx-value">81</span>\n</td>',
#  '<td>\n  <span class="wx-value">91</span>\n</td>',
# ...

# %%
[x.split('>')[2].split('<')[0] for x in raw_list]
# Out:
# ['77',
#  '73',
#  '77',
#  '88',
#  '89',
#  '76',
#  '77',
#  '89',
#  '85',
#  '85',
#  '84',
#  '76',
#  '79',
#  '86',
#  '81',
#  '70',
#  '81',
#  '91',
#  '82',
#  '81',
#  '74',
#  '73',
#  '63',
#  '69',
#  '70',
#  '74',
#  '81',
#  '77',
#  '72',
#  '82',
#  '79']
