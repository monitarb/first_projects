# %% [markdown]
# # GAME OF THRONES Death Prediction
#
# ## Predictions
#
# This sript will retrieve information from the .csv file saved on step 1 ([Load&Clean data](01_LoadClean_data.ipynb)) and the best Model chosen on step 3 ([Modeling data](03_GOT_ModelAnalysis.ipynb)) and perform a prediction on those characters who are still alive on season 7.
#
# If step 0 ([Load&Clean data](01_LoadClean_data.ipynb)) has already been executed **once** it will not be necessary to execute it again and you can start from here.

# %%
import pandas as pd
import numpy as np
import pickle

# %%
s7_df = pd.read_csv('csv/SQL_GOT_data.csv')
s7_df.columns
# Out:
# Index(['Unnamed: 0', 'name_x', 'isdead_bk', 'ismale', 'book1', 'book2',
#        'book3', 'book4', 'book5', 'isalivemother_bk',
#        ...
#        'house_bk[T.STONE CROWS]', 'house_bk[T.UNKNOWN]',
#        'house_shw[T.House Bolton]', 'house_shw[T.House Greyjoy]',
#        'house_shw[T.House Lannister]', 'house_shw[T.House Stark]',
#        'house_shw[T.House Targaryen]', 'house_shw[T.Nights Watch]',
#        'house_shw[T.None]', 'house_shw[T.Other]'],
#       dtype='object', length=122)

# %% [markdown]
# ### Update deaths from S7

# %%
deads6_list = ['Grenn', 'Janos Slynt', 'Doreah', 'Mace Tyrell', 'Brynden Tully', 'Xaro Xhoan Daxos', 'Kevan Lannister']
s7_df['isdead_shw'][s7_df['name_x'].isin(deads6_list)] = 1
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
s7_df['isdead_shw'][s7_df.name_x=='Leona Tyrell']=1
s7_df[s7_df.name_x=='Leona Tyrell'][['name_x', 'isdead_shw']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            name_x  isdead_shw
# 999  Leona Tyrell         1.0

# %%
s7_df['isdead_shw'][s7_df.name_x=='Taena of Myr']=1
s7_df[s7_df.name_x=='Taena of Myr'][['name_x', 'isdead_shw']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             name_x  isdead_shw
# 1733  Taena of Myr         1.0

# %%
s7_df['isdead_shw'][s7_df.name_x=='Petyr Baelish']=1
s7_df[s7_df.name_x=='Petyr Baelish'][['name_x', 'isdead_shw']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#              name_x  isdead_shw
# 1391  Petyr Baelish         1.0

# %%
s7_df['isdead_shw'][s7_df.name_x=='Kevan Lannister']=1
s7_df[s7_df.name_x=='Kevan Lannister'][['name_x', 'isdead_shw']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               name_x  isdead_shw
# 948  Kevan Lannister         1.0

# %%
s7_df['isdead_shw'][s7_df.name_x=='Benjen Stark']=1
s7_df[s7_df.name_x=='Benjen Stark'][['name_x', 'isdead_shw']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#            name_x  isdead_shw
# 202  Benjen Stark         1.0

# %% [markdown]
# ### Update House new allegiances from Season 7

# %%
s7_df['house_shw'][s7_df.name_x=='Brienne of Tarth']='House Stark'
s7_df['house_shw[T.House Stark]'][s7_df.name_x=='Brienne of Tarth']=1
s7_df['house_shw[T.Other]'][s7_df.name_x=='Brienne of Tarth']=0
s7_df[s7_df.name_x=='Brienne of Tarth'][['name_x', 'house_shw', 'house_shw[T.House Stark]']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                name_x    house_shw  house_shw[T.House Stark]
# 266  Brienne of Tarth  House Stark                       1.0

# %%
s7_df['house_shw'][s7_df.name_x=='Bronn']='House Lannister'
s7_df['house_shw[T.House Lannister]'][s7_df.name_x=='Bronn']=1
s7_df['house_shw[T.Other]'][s7_df.name_x=='Bronn']=0
s7_df[s7_df.name_x=='Bronn'][['name_x', 'house_shw', 'house_shw[T.House Lannister]']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     name_x        house_shw  house_shw[T.House Lannister]
# 268  Bronn  House Lannister                           1.0

# %%
s7_df['house_shw'][s7_df.name_x=='Jon Snow']='House Targaryen'
s7_df['house_shw[T.House Targaryen]'][s7_df.name_x=='Jon Snow']=1
s7_df['house_shw[T.Other]'][s7_df.name_x=='Jon Snow']=0
s7_df[s7_df.name_x=='Jon Snow'][['name_x', 'house_shw', 'house_shw[T.House Targaryen]', 'house_shw[T.Other]']]
# Out:
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\mramirbe\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        name_x        house_shw  house_shw[T.House Targaryen]  \
# 904  Jon Snow  House Targaryen                           1.0
#
#      house_shw[T.Other]
# 904                 0.0

# %%
s7_df[s7_df.isdead_shw==0].sort_values('total_viewers', ascending=False).head(40)['name_x']
# Out:
# 312       Cersei Lannister
# 1834      Tyrion Lannister
# 379     Daenerys Targaryen
# 904               Jon Snow
# 140             Arya Stark
# 910          Jorah Mormont
# 1633           Sansa Stark
# 829        Jaime Lannister
# 1630         Samwell Tarly
# 1631        Sandor Clegane
# 266       Brienne of Tarth
# 1877                 Varys
# 252          Brandon Stark
# 1760         Theon Greyjoy
# 268                  Bronn
# 1397         Podrick Payne
# 1217             Missandei
# 491        Eddison Tollett
# 667              Grey Worm
# 618                 Gendry
# 418         Davos Seaworth
# 1191            Melisandre
# 634                  Gilly
# 1177            Meera Reed
# 368         Daario Naharis
# 788                Hot Pie
# 662         Gregor Clegane
# 1451                Qyburn
# 111                  Anguy
# 835           Jaqen H'ghar
# 519           Ellaria Sand
# 213       Beric Dondarrion
# 1623        Salladhor Saan
# 1828        Tycho Nestoris
# 811        Illyrio Mopatis
# 883              Jon Arryn
# 1342    Osfryd Kettleblack
# 1331       Ormond (knight)
# 1332         Ormond Osgrey
# 1333     Ormond Westerling
# Name: name_x, dtype: object

# %%
len(s7_df[s7_df.isdead_shw==0])
# Out:
# 1935

# %%
s7_df = s7_df[s7_df.isdead_shw==0]#.sort_values('total_viewers', ascending=False).head(33)
#print(list(s7_df['name_x']))

# %%
y = s7_df['isdead_shw']
x = s7_df[['isdead_bk', 'ismale', 'book1', 'book2', 'book3', 'book4', 'book5',
            #'isalivemother_bk', 'isalivefather_bk', 'isaliveheir_bk','isalivespouse_bk', 'ismarried_bk', 
            'isnoble_bk', 'booldeadrelations_bk', 'ispopular_bk', #'death_bk', 'apperance_chp',
            #'hasmom_bk', 'hasdad_bk', 'hasheir_bk', 'hasspouse_bk', 
            'age_bk', 'numdeadrelations_bk', 'popularity_bk', 
            #'culture_bk', 'house_bk', 'name_y', 'isdead_shw', 'death_season', 
            'time_s1', 'time_s2', 'time_s3', 'time_s4', #'total_episode_num', 
            'season1', 'season2', 'season3', 'season4', 'age_shw', #'house_shw', 'match_name',
            #'sum_rating', 'total_viewers',
            'culture_bk[T.Astap]', 'culture_bk[T.Braav]', 'culture_bk[T.Crann]', 'culture_bk[T.Dorni]', 
            'culture_bk[T.Dothr]', 'culture_bk[T.Free ]', 'culture_bk[T.Ghisc]', 'culture_bk[T.Ironb]', 
            'culture_bk[T.Ironm]', 'culture_bk[T.Lhaza]', 'culture_bk[T.Lysen]', 'culture_bk[T.Myris]', 
            'culture_bk[T.Naath]', 'culture_bk[T.None]', 'culture_bk[T.North]', 'culture_bk[T.Pento]', 
            'culture_bk[T.Qarth]', 'culture_bk[T.Reach]', 'culture_bk[T.River]', 'culture_bk[T.Storm]', 
            'culture_bk[T.The R]', 'culture_bk[T.Tyros]', 'culture_bk[T.Valem]', 'culture_bk[T.Valyr]', 
            'culture_bk[T.Weste]', 'culture_bk[T.Wildl]',
            'house_bk[T.BROTHERHOOD WITHOUT BANNERS]', 'house_bk[T.HOUSE ARRYN]', 'house_bk[T.HOUSE BAELISH]', 
            'house_bk[T.HOUSE BARATHEON]', 'house_bk[T.HOUSE BOLTON]', 'house_bk[T.HOUSE CLEGANE]', 
            'house_bk[T.HOUSE FREY]', 'house_bk[T.HOUSE GREYJOY]', 'house_bk[T.HOUSE LANNISTER]', 
            'house_bk[T.HOUSE MARTELL]', 'house_bk[T.HOUSE STARK]', 'house_bk[T.HOUSE TARGARYEN]', 
            'house_bk[T.HOUSE TULLY]', 'house_bk[T.HOUSE TYRELL]', 'house_bk[T.NIGHTS WATCH]', 'house_bk[T.OTHER]', 
            'house_bk[T.UNKNOWN]', 'house_shw[T.House Bolton]', 'house_shw[T.House Greyjoy]', 
            'house_shw[T.House Lannister]', 'house_shw[T.House Stark]', 'house_shw[T.House Targaryen]', 
            'house_shw[T.None]', 'house_shw[T.Nights Watch]']]

# %%
def predict_s8(model_name) :
    with open("models/"+model_name+".pkl","rb") as f:
        model = pickle.load(f)
        
    return sorted(zip(s7_df.name_x, [i[1] for i in 100*(1-model.predict_proba(x))]), key=lambda tup: tup[1], reverse=True)

# %%
predict_s8('inner_reglog')
# Out:
# [('Tyrion Lannister', 98.8324855078665),
#  ('Jon Snow', 98.24011831874925),
#  ('Sansa Stark', 92.2363782558126),
#  ('Theon Greyjoy', 92.09401208209167),
#  ('Arya Stark', 91.4899651859474),
#  ('Daenerys Targaryen', 90.63198727988436),
#  ('Missandei', 89.73684913280766),
#  ('Sandor Clegane', 86.42041533586591),
#  ('Jaime Lannister', 84.79796876538742),
#  ('Cersei Lannister', 81.63947653537646),
#  ('Jorah Mormont', 81.38066964453662),
#  ('Brienne of Tarth', 81.01505377611761),
#  ('Samwell Tarly', 80.10224971060876),
#  ('Melisandre', 78.47797772633544),
#  ('Gilly', 76.71861118527711),
#  ('Varys', 76.23553391083449),
#  ('Davos Seaworth', 75.84143296758235),
#  ('Gendry', 75.0064847729984),
#  ('Brandon Stark', 71.75881689489394),
#  ('Robert Arryn', 71.33953872712115),
#  ('Meera Reed', 68.75750813987167),
#  ('Alysane Mormont', 67.97217198354353),
#  ('Grey Worm', 64.9356309543595),
#  ('Illyrio Mopatis', 64.87365218463881),
#  ('Daario Naharis', 64.58592976867375),
#  ('Monster', 64.05127418037726),
#  ('Podrick Payne', 63.14111027769791),
#  ('Janei Lannister', 60.51560981799129),
#  ('Loreza Sand', 60.42367618026816),
#  ('Ysilla Royce', 59.94863477385868),
#  ('Shirei Frey', 58.99770888177296),
#  ('Harrold Hardyng', 58.714803945376694),
#  ('Jhiqui', 58.632148452110535),
#  ('Tyrion Tanner', 58.11457486137024),
#  ('Wulfe', 58.05951825327726),
#  ('Wex Pyke', 57.69537014379673),
#  ('Asha Greyjoy', 57.60875028716272),
#  ('Eddison Tollett', 57.067272057466134),
#  ('Jhogo', 56.56354139843012),
#  ('Elmar Frey', 56.114387477917305),
#  ('Joy Hill', 56.06399406761935),
#  ('Creighton Redfort', 55.93721532884348),
#  ('Jasper Redfort', 55.93721532884348),
#  ('Jon Redfort', 55.93721532884348),
#  ('Alla Tyrell', 55.5294758994638),
#  ('Megga Tyrell', 55.505708732761775),
#  ('Elinor Tyrell', 55.43439216200377),
#  ('Arwyn Frey', 55.06800102609654),
#  ('Mela', 54.83291736210548),
#  ('Olyvar Frey', 54.81188378380642),
#  ('Maddy', 54.809080884888274),
#  ('Dorea Sand', 54.77905720557212),
#  ('Maron Greyjoy', 54.484129937332426),
#  ('Jon Myre', 54.46978396233544),
#  ('Beth Cassel', 54.4039652153258),
#  ('Obella Sand', 54.1523582233707),
#  ('Alys Karstark', 54.13940589410746),
#  ('Horton Redfort', 54.1359542774792),
#  ('Waltyr Frey', 54.03286044476292),
#  ('Willem Frey', 53.81765390020475),
#  ('Eleanor Mooton', 53.64853366573694),
#  ('Lyanna Mormont', 53.52709332742928),
#  ('Colmar Frey', 53.490407889196256),
#  ('Melara Hetherspoon', 53.43718937758349),
#  ('Nymeria Sand', 53.30112963739777),
#  ('Elia Sand', 52.923154181468604),
#  ('Daegon Shepherd', 52.880000346115594),
#  ('Lucas Codd', 52.83203703280378),
#  ('Beric Dondarrion', 52.74541080293713),
#  ('Waif', 52.707425035491354),
#  ('Bronn', 52.61036701144164),
#  ('Wendel Frey', 52.33113100786249),
#  ('Wylla Manderly', 52.22562473174713),
#  ('Dickon Tarly', 52.0501716377003),
#  ('Ellaria Sand', 51.89852179730803),
#  ('Gretchel', 51.50129330576634),
#  ('Maron Volmark', 51.45294935692779),
#  ('Rodrik Greyjoy', 51.14279497531417),
#  ('Andar Royce', 50.98633011230614),
#  ('Steffon Seaworth', 50.888779005506436),
#  ('Falia Flowers', 50.830984105256135),
#  ('Tyrek Lannister', 50.7782698645242),
#  ('Mychel Redfort', 50.76985579191182),
#  ('Groleo', 50.57995712703338),
#  ('Nute', 50.3776164430038),
#  ('Aggo', 50.24756684219016),
#  ('Dagon Greyjoy', 50.20920127840294),
#  ('Sarella Sand', 50.17470156758694),
#  ('Wynafryd Manderly', 50.044913216622824),
#  ('Jorelle Mormont', 49.926695063880835),
#  ('Belwas', 49.912271727349065),
#  ('Mord', 49.72479410683967),
#  ('Alysanne Bulwer', 49.69919072139317),
#  ('Old Grey Gull', 49.63313034064054),
#  ('Quellon Humble', 49.560954559783454),
#  ('Jeyne Poole', 49.47294178846493),
#  ('Beren Tallhart', 49.46304202678168),
#  ('Cyrenna Swann', 49.441885582516974),
#  ('Kindly man', 49.41191461517638),
#  ('Ralf the Limper', 49.41191461517638),
#  ('Lyra Mormont', 49.35712448617734),
#  ('Alannys Harlaw', 49.121444599466315),
#  ('Ermesande Hayford', 49.11395725628981),
#  ('Qyburn', 48.76448177608283),
#  ('Lanna Lannister', 48.69540388869106),
#  ('Stannis Seaworth', 48.65889088594094),
#  ('Willow Heddle', 48.59296396528055),
#  ('Harwin', 48.54714232662809),
#  ('Alayaya', 47.82652535930572),
#  ('Ronel Rivers', 47.795817561045354),
#  ('Martyn Rivers', 47.74779280787885),
#  ('Tyene Sand', 47.657393219780644),
#  ('Leana Frey', 47.56110088908023),
#  ('Mya Stone', 47.45994076638671),
#  ('Kemmett Pyke', 47.2660845469052),
#  ('Stonehand', 47.2660845469052),
#  ('Devan Seaworth', 47.25745087592886),
#  ('Qarl the Thrall', 47.21811063139453),
#  ('Red Oarsman', 47.21811063139453),
#  ('Kyra', 47.15277383100158),
#  ('Grazdan mo Eraz', 47.0830332940086),
#  ('Jack Bulwer', 46.98288238170076),
#  ('Val', 46.89842275701051),
#  ('Barth', 46.83413560080787),
#  ('Nan', 46.75201023238693),
#  ('Brandon Tallhart', 46.69201129066152),
#  ('Aglantine', 46.49882840970388),
#  ('Scolera', 46.47488703149302),
#  ('Unella', 46.45094727769315),
#  ('Luwin', 46.425670991371874),
#  ('Moelle', 46.37913787194828),
#  ('Myranda Royce', 46.363371600916025),
#  ('Mellara Rivers', 46.195677810975276),
#  ('Jeyne Rivers', 46.17175781590615),
#  ('Mago', 46.1265868523945),
#  ('Yohn Royce', 46.058943457155685),
#  ('Qarl the Maid', 46.01794286053216),
#  ('Josmyn Peckledon', 45.868104020242384),
#  ('Tyta Frey', 45.693742494402),
#  ('Omer Blackberry', 45.67734411150391),
#  ('Meredyth Crane', 45.62958743683359),
#  ('Cerenna Lannister', 45.524092799808116),
#  ('Myrielle Lannister', 45.524092799808116),
#  ('Amarei Crakehall', 45.4831901646362),
#  ('Eddara Tallhart', 45.430215541061095),
#  ('Shiera Crakehall', 45.36707165131655),
#  ('Triston Farwynd', 45.36031425617576),
#  ('Kerwin', 45.346046020377116),
#  ('Cragorn', 45.25022014015616),
#  ('Ghost of High Heart', 45.22398879113759),
#  ('Tywin Frey', 45.14094676117028),
#  ('Dagmer', 45.02756454814312),
#  ('Obara Sand', 44.80243070387701),
#  ('Shagga', 44.78003165280635),
#  ('Ryger Rivers', 44.70560524171646),
#  ('Merrett Frey', 44.50956780340071),
#  ('Ryk', 44.43741371230846),
#  ('Noho Dimittis', 44.3772610066035),
#  ('Benfred Tallhart', 44.269744789575746),
#  ('Brusco', 44.139832381897804),
#  ('Beron Blacktyde', 44.09564612367598),
#  ('Jocelyn Swyft', 44.09564612367598),
#  ('Jeyne Heddle', 44.06387299509663),
#  ('Aurane Waters', 44.06268520264647),
#  ('Rosamund Lannister', 44.04820222581131),
#  ('Tim Tangletongue', 44.01429738275089),
#  ('Halder', 44.00754773917096),
#  ('Goady', 43.99058340725518),
#  ('Rodrik Freeborn', 43.97058988142014),
#  ('Harren Half-Hoare', 43.946880969687996),
#  ('Jaime Frey', 43.906452874495535),
#  ('Leona Woolfield', 43.882234729876046),
#  ('Tywin Frey (son of Raymund)', 43.85905283599322),
#  ('Ramsay Snow', 43.84311141673201),
#  ('Tristifer Botley', 43.713320329334415),
#  ('Marei', 43.662623616401476),
#  ('Quaithe', 43.653330538486756),
#  ('Gylbert Farwynd', 43.539257119031326),
#  ('Tion Frey', 43.53425453899305),
#  ('Osmund Frey', 43.412284855051745),
#  ('Jyana', 43.28275023559325),
#  ('Dalla', 43.24166152310532),
#  ('Ollidor', 43.21299203796174),
#  ('Torbert', 43.21299203796174),
#  ('Raynard', 43.18937673966005),
#  ('Ragnor Pyke', 43.047285291134344),
#  ('Myria Jordayne', 43.02265241738682),
#  ('Ragwyle', 43.01742669477011),
#  ('Garrett Flowers', 42.85538689060758),
#  ('Della Frey', 42.85342979758835),
#  ('Bran the Builder', 42.84422694080091),
#  ('Emberlei Frey', 42.64144470840295),
#  ('Mina Tyrell', 42.61986170246362),
#  ('Orland of Oldtown', 42.54463920107593),
#  ('Janna Tyrell', 42.52574467016619),
#  ('Igon Vyrwel', 42.492570219413025),
#  ('Tobho Mott', 42.3482890093232),
#  ('Anguy', 42.339689573911485),
#  ('Ulmer', 42.21562143470094),
#  ('Oswell Kettleblack', 42.19214621979478),
#  ('Arianne Martell', 42.158031247582706),
#  ('Norne Goodbrother', 42.149675824964405),
#  ('Meldred Merlyn', 42.12621054700081),
#  ('Colemon', 42.08717650765933),
#  ('Merling Queen', 42.00470008435152),
#  ('Ralf Stonehouse', 41.97438870479362),
#  ('Walda Rivers', 41.85837045329299),
#  ('Byron', 41.83089875494067),
#  ('Boremund Harlaw', 41.76357413783246),
#  ('Sigfryd Harlaw', 41.76357413783246),
#  ('Blue Bard', 41.69930670925734),
#  ('Hamish the Harper', 41.6890686777405),
#  ('Coldhands', 41.6766017930079),
#  ('Hotho Harlaw', 41.66997482553075),
#  ('Roose Ryswell', 41.65309459174716),
#  ('Margot Lannister', 41.60013558769522),
#  ('Rickard Ryswell', 41.58294261475667),
#  ('Roger Ryswell', 41.53619355148308),
#  ('Satin', 41.52462354902768),
#  ('Mathis Frey', 41.50745571161447),
#  ('Berena Hornwood', 41.500528382467024),
#  ('Walda Frey (daughter of Lothar)', 41.48409158188129),
#  ('Harras Harlaw', 41.459596753294946),
#  ('Dunsen', 41.456276234428266),
#  ('Elwood', 41.394109173718704),
#  ('Perra Frey', 41.39067345590015),
#  ('Lucion Lannister', 41.273175060344414),
#  ('Ryella Frey', 41.13409468399979),
#  ('Hazzea', 40.992731860018516),
#  ('Rhaegar Frey', 40.91858114148437),
#  ('Garrett Paege', 40.89648355094687),
#  ('Selyse Florent', 40.83108207132109),
#  ('Spare Boot', 40.79348114723018),
#  ('Dancy', 40.7912331906734),
#  ('Kegs', 40.77023878346969),
#  ('Left Hand Lew', 40.77023878346969),
#  ('Tim Stone', 40.77023878346969),
#  ('Black Bernarr', 40.74700054847889),
#  ('Salladhor Saan', 40.696337956442385),
#  ('Quentyn Martell', 40.666384502128494),
#  ('Hop-Robin', 40.65408908928346),
#  ('Owen', 40.63087164288049),
#  ('Arron', 40.58444931953271),
#  ('Donnel Hill', 40.58444931953271),
#  ('Emrick', 40.58444931953271),
#  ('Mully', 40.53804381952661),
#  ('Lewys Piper', 40.41678162695972),
#  ('Tysane Frey', 40.405564196068596),
#  ('Mikken', 40.39155106164842),
#  ('Jarl', 40.29137097378237),
#  ('Garth Greenfield', 40.19729485679656),
#  ('Ollo Lophand', 40.130300931872384),
#  ('Nysterica', 40.10673855394534),
#  ('Jonos Frey', 40.065965767118925),
#  ('Cersei Frey', 40.05843749732201),
#  ('Grubbs', 39.99482549834873),
#  ('Orphan Oss', 39.97173096608314),
#  ('Lysono Maar', 39.93837625929949),
#  ('Regenard Estren', 39.924268102192016),
#  ('Hairy Hal', 39.90247415128424),
#  ('Victarion Greyjoy', 39.82655601958087),
#  ('Bethany Rosby', 39.81958260697602),
#  ('Edric Storm', 39.7526885325994),
#  ('Garse Flowers', 39.659301297778114),
#  ('Domeric Bolton', 39.63493282049886),
#  ('Moryn Tyrell', 39.59022879143299),
#  ('Lynesse Hightower', 39.57886772172693),
#  ('Donel Greyjoy', 39.501359215865776),
#  ('Quenton Greyjoy', 39.501359215865776),
#  ('Harlon Greyjoy', 39.478362159141845),
#  ('Robin Greyjoy', 39.478362159141845),
#  ('Donnel Waynwood', 39.356578509601725),
#  ('Elron', 39.29250747902944),
#  ('Old Tattersalt', 39.21279008331621),
#  ('Conwy', 39.20071839677413),
#  ('Robett Glover', 39.20017266690964),
#  ('Merrit', 39.188939198075786),
#  ('Walda Frey (daughter of Edwyn)', 39.17558326662211),
#  ('Likely Luke', 39.166006276772094),
#  ('Notch', 39.166006276772094),
#  ('Watty', 39.166006276772094),
#  ('Bearded Ben', 39.14399075804537),
#  ('Beardless Dick', 39.12015478867584),
#  ('Willas Tyrell', 39.10043171742408),
#  ('Erena Glover', 39.09353616788265),
#  ('Lenyl', 39.04705901292081),
#  ('Joyeuse Erenford', 39.042113774384966),
#  ('Dryn', 39.00125750070357),
#  ('Moon Boy', 38.961078921695844),
#  ('Patrek Mallister', 38.961078921695844),
#  ('Waldon Wynch', 38.94744201305011),
#  ('Munda', 38.93259160888489),
#  ('Toregg', 38.93259160888489),
#  ('Lanna (Happy Port)', 38.903474515863266),
#  ('Cynthea Frey', 38.90073956508117),
#  ('Urrigon Greyjoy', 38.86668105324701),
#  ('Tremond Gargalen', 38.833897573094724),
#  ('Delonne Allyrion', 38.81103981679092),
#  ('Andrik', 38.810223006215985),
#  ('Cley Cerwyn', 38.753990021819554),
#  ('Butterbumps', 38.72463738930928),
#  ('Nymella Toland', 38.696825048932446),
#  ('Morgarth', 38.68235340671442),
#  ('Jon Connington', 38.66746882644886),
#  ('Gorold Goodbrother', 38.559116484559055),
#  ('Androw Frey', 38.54199613585472),
#  ('Alyn Frey', 38.51920199415283),
#  ('Gormond Goodbrother', 38.50759666620319),
#  ('Mag Mar Tun Doh Weg', 38.384668729800396),
#  ('Terrence Kenning', 38.37108229401148),
#  ('Selmond Stackspear', 38.348326160895766),
#  ('Alyce Graceford', 38.32557513079169),
#  ('Gerald Gower', 38.32557513079169),
#  ('Lester Morrigen', 38.32557513079169),
#  ('Dickon Frey', 38.32169247318286),
#  ('Triston of Tally Hill', 38.28008841487558),
#  ('Azor Ahai', 38.24706656038309),
#  ('Merianne Frey', 38.231549173911404),
#  ('Walton', 38.15652471986303),
#  ('Rodrik Harlaw', 38.01337260281282),
#  ('Damion Lannister', 38.00294101832547),
#  ('Cotter Pyke', 37.98804598161367),
#  ('Ralf Kenning', 37.96936910261965),
#  ('Aeron Greyjoy', 37.95519718977612),
#  ('Waymar Royce', 37.90032653982427),
#  ('Gerion Lannister', 37.87566445488303),
#  ('Willem Lannister', 37.84536266558172),
#  ('Uthor Tollett', 37.79044050315211),
#  ('Cuger', 37.78067069854391),
#  ('Serra', 37.710324707931974),
#  ('Alyn Ambrose', 37.69286437225684),
#  ('Jeren', 37.690220669212074),
#  ('Theodan Wells', 37.667942682534836),
#  ('Matthar', 37.66762152864492),
#  ('Torren Liddle', 37.645348829512514),
#  ('Meg', 37.63090505769655),
#  ('Albett', 37.59985632416723),
#  ('Cellador', 37.59985632416723),
#  ('Morya Frey', 37.57799184298395),
#  ('Hobb', 37.53213962479717),
#  ('Harys Swyft', 37.50295750379623),
#  ('Eleyna Westerling', 37.49881917855582),
#  ('Orton Merryweather', 37.4398407744853),
#  ('Hot Pie', 37.42088123856696),
#  ('Daeron Vaith', 37.37138241439495),
#  ('Robert Frey', 37.31882454518014),
#  ('Leonette Fossoway', 37.30720178277957),
#  ('Jon Brax', 37.29650795282197),
#  ('Sandor Frey', 37.26648071196915),
#  ('Falyse Stokeworth', 37.22126344696828),
#  ('Patchface', 37.19692140773505),
#  ('Dywen', 37.194291724540506),
#  ('Rafford', 37.17609772691205),
#  ('Lomas Estermont', 37.03515106037892),
#  ('Gerold Dayne', 36.994774648199815),
#  ('Paxter Redwyne', 36.9211234596001),
#  ('Del', 36.910531157435855),
#  ('Zia Frey', 36.876982523146076),
#  ('Muttering Bill', 36.87441395472416),
#  ('Humfrey Swyft', 36.87066398092639),
#  ('Lorent Lorch', 36.87066398092639),
#  ('Lucimore Botley', 36.860451962830155),
#  ('Mawney', 36.852014668952236),
#  ('Alysanne Lefford', 36.8482656433828),
#  ('Lucas Corbray', 36.8482656433828),
#  ('Clubfoot Karl', 36.82962105114199),
#  ('Small Paul', 36.82962105114199),
#  ('Jon Bettley', 36.82587297517684),
#  ('Rolland Longthorpe', 36.82587297517684),
#  ('Trebor Jordayne', 36.82587297517684),
#  ('Perwyn Frey', 36.82135717445524),
#  ('Garth of Greenaway', 36.807233109509156),
#  ('Bayard Norcross', 36.80348598452268),
#  ('Manfryd Yew', 36.80348598452268),
#  ('Moribald Chester', 36.80348598452268),
#  ('Raynard Ruttiger', 36.80348598452268),
#  ('Delp', 36.791180617954346),
#  ('Bluetooth', 36.78627803015557),
#  ('Quenten Banefort', 36.783602927756874),
#  ('Corliss Penny', 36.781104679625074),
#  ('Eustace Hunter', 36.781104679625074),
#  ('Jon Lynderly', 36.781104679625074),
#  ('Quentyn Qorgyle', 36.781104679625074),
#  ('Osbert Serry', 36.758729068679365),
#  ('Rufus Leek', 36.758729068679365),
#  ('Symond Templeton', 36.73635915987145),
#  ('Mors Martell (brother of Doran)', 36.73188553776945),
#  ('Uller', 36.719164355262954),
#  ('Dirk', 36.71773826873736),
#  ('Barbrey Dustin', 36.67900719668573),
#  ('Garth Greyfeather', 36.67302511833243),
#  ('Marissa Frey', 36.64596006374495),
#  ('Daven Lannister', 36.6346793042326),
#  ('Godric Borrell', 36.59918398121362),
#  ('Walder Rivers', 36.51607911256185),
#  ('Robar Royce', 36.483619228755515),
#  ('Walder Haigh', 36.482113485166224),
#  ('Rickard Wylde', 36.45255206415708),
#  ('Tal Toraq', 36.37259985413003),
#  ('Alys Arryn', 36.363410760650986),
#  ('Ben', 36.32285123167698),
#  ('Sarra Frey', 36.27419726700768),
#  ('Serra Frey', 36.27419726700768),
#  ('Randyll Tarly', 36.206812392656204),
#  ('Torrhen Karstark', 36.15794259280324),
#  ('Clement Piper', 36.14460603242973),
#  ('Jeyne Goodbrook', 36.04448122727404),
#  ('Rollam Westerling', 36.04322809834949),
#  ('Jon Umber (Smalljon)', 36.02751563554117),
#  ('Eddard Karstark', 36.00533736823461),
#  ('Sarya Whent', 35.98337485201482),
#  ('Jack-Be-Lucky', 35.98266262145704),
#  ('Bedwyck', 35.94971600919644),
#  ('Mad Huntsman', 35.91618206589517),
#  ('Tormund', 35.89933393504396),
#  ('Benfrey Frey', 35.79968254487929),
#  ('Walder Brax', 35.690276408936484),
#  ('Whalen Frey', 35.65731843049833),
#  ('Lem', 35.60665745149525),
#  ('Ryon Allyrion', 35.55139174390855),
#  ('Manfrey Martell', 35.516771161647966),
#  ('Daemon Sand', 35.419196291863685),
#  ('Qarl Kenning', 35.41754548421076),
#  ('Qarl Shepherd', 35.41754548421076),
#  ('Lythene Frey', 35.34365576211938),
#  ('Alyn Stackspear', 35.32010954863115),
#  ('Vortimer Crane', 35.32010954863115),
#  ('Bradamar Frey', 35.31467262023094),
#  ('Titus Peake', 35.28084505051247),
#  ('Ulwyck Uller', 35.28084505051247),
#  ('Lewys Lydden', 35.254178990906404),
#  ('Jalabhar Xho', 35.25115335930108),
#  ('Harlan Hunter', 35.24377261180385),
#  ('Deziel Dalt', 35.23690736614673),
#  ('Glendon Hewett', 35.23690736614673),
#  ('Lymond Goodbrook', 35.23690736614673),
#  ('Vyman', 35.232214598348136),
#  ('Philip Plumm', 35.21494788160854),
#  ('Steffon Swyft', 35.21494788160854),
#  ('Qezza', 35.19343623290868),
#  ('Dagos Manwoody', 35.19299464551151),
#  ('Kennos of Kayce', 35.19299464551151),
#  ('Norbert Vance', 35.17104766535153),
#  ('Bella', 35.14664612691869),
#  ('Dormund', 35.130208373024),
#  ('Torwynd', 35.130208373024),
#  ('Harmen Uller', 35.12717250277616),
#  ('Theomar Smallwood', 35.12717250277616),
#  ('Gilbert Farring', 35.10524433530229),
#  ('Gascoyne', 35.092740090136),
#  ('Anders Yronwood', 35.017594598012394),
#  ('Arthur Ambrose', 35.017594598012394),
#  ('High Sparrow', 35.00344879035936),
#  ('Gawen Glover', 35.00195294447755),
#  ('Rolland Storm', 34.95192358218975),
#  ('Roryn Drumm', 34.93860010995877),
#  ('Anya Waynwood', 34.92537196971176),
#  ('Zachery Frey', 34.89047549991998),
#  ('Gwin Goodbrother', 34.7856170388702),
#  ('Gysella Goodbrother', 34.7856170388702),
#  ('Ricasso', 34.72099059643635),
#  ('Gregor Clegane', 34.71043627279481),
#  ('Thoros', 34.696517935807925),
#  ('Alyx Frey', 34.66583670568784),
#  ('Hoster Frey', 34.6067963557514),
#  ('Gwynesse Harlaw', 34.58938520345076),
#  ('Lyessa Flint', 34.56930674062397),
#  ('Mathis Rowan', 34.55202089073115),
#  ('Brandon Norrey', 34.537232305786894),
#  ('Garlan Tyrell', 34.49599470062964),
#  ('Ben Plumm', 34.49383465419109),
#  ('Hugo Wull', 34.49372711994471),
#  ('Rodrik Ryswell', 34.47198425917152),
#  ('Renly Norcross', 34.46176387957727),
#  ('Harwood Stout', 34.38507786401045),
#  ('Sybelle Glover', 34.35194511097481),
#  ('Franklyn Fowler', 34.273452510100086),
#  ('Nymeria', 34.21338031663886),
#  ('Gyles Rosby', 34.15419484653184),
#  ('Jeyne Westerling', 34.11782383413805),
#  ('Sebaston Farman', 34.11156449117594),
#  ('Pono', 34.07820148708273),
#  ('Alyn Estermont', 34.05797231609454),
#  ('Aemon Estermont', 34.03636141200015),
#  ('Jhaqo', 34.03497389830742),
#  ('Symeon Star-Eyes', 34.02471278414484),
#  ('Bryen Farring', 33.94425848048287),
#  ('Penny', 33.93849383292971),
#  ('Benedict Broom', 33.86668261184751),
#  ('Tybolt Hetherspoon', 33.85647162975548),
#  ('Bennarion Botley', 33.84664685264459),
#  ('Harlon Botley', 33.84664685264459),
#  ('Quellon Botley', 33.84664685264459),
#  ('Symond Botley', 33.84664685264459),
#  ('Vickon Botley', 33.84664685264459),
#  ('Tanton Fossoway', 33.845130788570245),
#  ('Arnolf Karstark', 33.84429651836937),
#  ('Garrison Prester', 33.83492297998551),
#  ('Robin Moreland', 33.83492297998551),
#  ('Balon Botley', 33.82510125824547),
#  ('Vylarr', 33.819158393501645),
#  ('Guthor Grimm', 33.813381033980114),
#  ('Lambert Turnberry', 33.813381033980114),
#  ('Rennifer Longwaters', 33.813381033980114),
#  ('Symon Santagar', 33.813381033980114),
#  ('Sargon Botley', 33.80356237073232),
#  ('Gerold Grafton', 33.770317280628134),
#  ('Renfred Rykker', 33.770317280628134),
#  ('Marya Seaworth', 33.75630954457613),
#  ('Benedar Belmore', 33.7487954869379),
#  ('Wallace Waynwood', 33.7487954869379),
#  ('Humfrey Hewett', 33.72728042432487),
#  ('Triston Sunderland', 33.72728042432487),
#  ('Frenken', 33.715960799141165),
#  ('Jammos Frey', 33.70800725778146),
#  ('Balon Swann', 33.70767671949573),
#  ('Leyton Hightower', 33.704468710934364),
#  ('Iron Emmett', 33.701883649119914),
#  ('Lucas Blackwood', 33.685790178802364),
#  ('Clayton Suggs', 33.641287620526484),
#  ('Marlon Manderly', 33.641287620526484),
#  ('Annara Farring', 33.58703350097117),
#  ('Harmune', 33.546186774083154),
#  ('Godry Farring', 33.51250149866897),
#  ('Richard Horpe', 33.51250149866897),
#  ('Lothar Frey', 33.48514977195771),
#  ('Jonos Bracken', 33.44690176532452),
#  ('Leslyn Haigh', 33.43692700169668),
#  ('Justin Massey', 33.405366814699576),
#  ('Shella Whent', 33.31312232967662),
#  ('Martyn Lannister', 33.300426639861556),
#  ('Dacey Mormont', 33.232653403807475),
#  ('Shortear', 33.19731005532287),
#  ('Harren Botley', 33.06532895250969),
#  ('Symon Stripeback', 33.01770622723205),
#  ('Dareon', 32.99883645832713),
#  ('Yandry', 32.97515095726248),
#  ('Jacks', 32.95210380368967),
#  ('Ronnet Connington', 32.86726349983864),
#  ('Malwyn Frey', 32.77906574705857),
#  ('Pylos', 32.72569100020911),
#  ('Styr', 32.701056547525184),
#  ('Tycho Nestoris', 32.66371470495192),
#  ('Galbart Glover', 32.566779206779515),
#  ('Haldon', 32.487782125204355),
#  ('Garth Tyrell', 32.48177662393745),
#  ('Ebben', 32.3267362723662),
#  ('Albar Royce', 32.32556225076155),
#  ('Gawen Westerling', 32.32165814442078),
#  ('Arwyn Oakheart', 32.30451209302434),
#  ('Morton Waynwood', 32.30451209302434),
#  ('Mullin', 32.293123247686125),
#  ('Tytos Brax', 32.26243328933326),
#  ('Belaquo', 32.246320401772046),
#  ('Goghor', 32.246320401772046),
#  ('Ithoke', 32.246320401772046),
#  ('The Red Lamb', 32.246320401772046),
#  ('Robert Frey (son of Raymund)', 32.215931201205784),
#  ('Willam Dustin', 32.16773893489356),
#  ('Jon Umber (Greatjon)', 32.166496778958454),
#  ('Raymund Frey', 32.149175199684),
#  ('Holly', 32.14358757030329),
#  ('Othell Yarwyck', 32.136369408860446),
#  ('Myles', 32.08692486872733),
#  ('Elwood Meadows', 32.07547726870186),
#  ('Sigfry Stonetree', 32.00228637408286),
#  ('Nestor Royce', 31.989623339771324),
#  ('Gormond Drumm', 31.98134724678595),
#  ('Hilmar Drumm', 31.98134724678595),
#  ('Lyn Corbray', 31.96868860256573),
#  ('Alvyn Sharp', 31.960415380449327),
#  ('Emmond', 31.960415380449327),
#  ('Gyles Farwynd', 31.960415380449327),
#  ('Harmund Sharp', 31.960415380449327),
#  ('Lenwood Tawney', 31.960415380449327),
#  ('Yohn Farwynd', 31.960415380449327),
#  ('Ferrego Antaryon', 31.95243551082143),
#  ('Will Humble', 31.939490780985636),
#  ('Wun Weg Wun Dar Wun', 31.931731315125976),
#  ('Dagon Ironmaker', 31.918573454296705),
#  ('Denys Drumm', 31.918573454296705),
#  ('Donnel Drumm', 31.918573454296705),
#  ('Eldred Codd', 31.918573454296705),
#  ('Thormor Ironmaker', 31.918573454296705),
#  ('Urek Ironmaker', 31.918573454296705),
#  ('Romny Weaver', 31.897663406273537),
#  ('Steffarion Sparr', 31.897663406273537),
#  ('Gran Goodbrother', 31.85586516973421),
#  ('Tarle', 31.85586516973421),
#  ('Bethany Bolton', 31.818405699726892),
#  ('Helya', 31.798655733116377),
#  ('Garin (Orphan)', 31.768285556231724),
#  ('Shadrich', 31.768285556231724),
#  ('Lum', 31.74891115812455),
#  ('Greydon Goodbrother', 31.730645757396147),
#  ('Addam Marbrand', 31.718040071384124),
#  ('Lothor Brune', 31.67636773055813),
#  ('Flement Brax', 31.655542576616057),
#  ('Ondrew Locke', 31.648931731342245),
#  ('Gormon Tyrell', 31.57231553812503),
#  ('Barsena', 31.56746485729477),
#  ('Symond Frey', 31.56333873063566),
#  ('Walder Goodbrook', 31.546830919022273),
#  ('Lanna', 31.529842619709857),
#  ('Terrence Toyne', 31.525481053735593),
#  ('Bryan Frey', 31.51910584175096),
#  ('Lester', 31.502048217642454),
#  ('Alester Norcross', 31.463758116847607),
#  ('Ilyn Payne', 31.4438489959343),
#  ('Jason Mallister', 31.434021273259873),
#  ('Marq Piper', 31.35110948144384),
#  ('Denyo Terys', 31.33840261750198),
#  ('Balman Byrch', 31.31809746396883),
#  ('Tanda Stokeworth', 31.311095630096396),
#  ('Ossifer Plumm', 31.235352145841134),
#  ('Robert Brax (son of Flement)', 31.2152519848519),
#  ('Boros Blount', 31.178604694013245),
#  ('Tytos Blackwood', 31.157957550957494),
#  ('Norjen', 31.099814245781467),
#  ('Arys Oakheart', 31.084127246551606),
#  ('Rus', 31.079195716858987),
#  ('Halmon Paege', 30.99814393667072),
#  ('Monterys Velaryon', 30.98518914255849),
#  ('Lymond Vikary', 30.93642225810489),
#  ('Ballabar', 30.915863448471203),
#  ('Togg Joth', 30.877888014432852),
#  ('Andrew Estermont', 30.874768486239013),
#  ('William Mooton', 30.833703769022236),
#  ('Tallad', 30.81318276561682),
#  ('Mark Mullendore', 30.792669339430024),
#  ('Bonifer Hasty', 30.77216349576064),
#  ('Caleotte', 30.639904779459226),
#  ('Antario Jast', 30.608390349279446),
#  ('Khrazz', 30.578672198807034),
#  ('Osfryd Kettleblack', 30.567523255440477),
#  ('Lyle Crakehall', 30.445105500840807),
#  ('Grigg', 30.43553948766532),
#  ('Larence Snow', 30.409751175682487),
#  ('Walda Rivers (daughter of Aemon)', 30.39877271042566),
#  ('Osney Kettleblack', 30.343301608154206),
#  ('Luco Prestayn', 30.322939581687812),
#  ('Bellonara Otherys', 30.26197270819192),
#  ('Kojja Mo', 30.241665843239495),
#  ('Turnip', 30.204574924041538),
#  ('Harwood Fell', 30.18201544324398),
#  ('Meralyn', 30.180791597066115),
#  ('Quent', 30.166275885194118),
#  ('Mossador', 30.15807343866481),
#  ('Alerie Hightower', 30.151146234880986),
#  ('Puckens', 30.118613758954282),
#  ('Lucias Vypren', 30.099758483055293),
#  ('Dorcas', 30.078117146125827),
#  ('Osmund Kettleblack', 30.059276317283224),
#  ('Dolf', 30.02534438593738),
#  ('Fat Walda Frey', 30.004298556093833),
#  ('Petyr Frey', 29.998923408257216),
#  ('Cletus Yronwood', 29.939210441662322),
#  ('Tregar Ormollen', 29.898587090992244),
#  ('Alyssa Blackwood', 29.847918485550807),
#  ('Danny Flint', 29.81210029140029),
#  ('Oppo', 29.697426783483806),
#  ('Barbara Bracken', 29.649621653031268),
#  ('Bess Bracken', 29.649621653031268),
#  ('Catelyn Bracken', 29.649621653031268),
#  ('Jayne Bracken', 29.649621653031268),
#  ('Cleos Frey', 29.647480224482003),
#  ('Alysanne Bracken', 29.629551114686038),
#  ('Reek', 29.551061114272002),
#  ('Maris', 29.51411753242037),
#  ('Meha', 29.51411753242037),
#  ('Bowen Marsh', 29.473455223020828),
#  ('Luceon Frey', 29.42650544886469),
#  ('Axell Florent', 29.393345859072205),
#  ('Eglantine', 29.3329465781488),
#  ('Eustace (Braavos)', 29.313001084969436),
#  ('Harrion Karstark', 29.297005084435057),
#  ('Rodrik Stark (son of Beron)', 29.245325144812007),
#  ('Roslin Frey', 29.114242838669767),
#  ('Leyla Hightower', 29.074275796221883),
#  ('Jynessa Blackmont', 29.073010201906357),
#  ('Alysanne Hightower', 29.034599952814432),
#  ('Helman Tallhart', 29.0304350591968),
#  ('Lyonel Corbray', 29.00861730356441),
#  ('Melwys Rivers', 28.968351331508092),
#  ('Denyse Hightower', 28.935550459491576),
#  ('Lorent Tyrell', 28.91688157779848),
#  ('Olene Tyrell', 28.91688157779848),
#  ('Lyonel Tyrell (son of Leo)', 28.897103308094753),
#  ('Quellon Greyjoy', 28.894066874948354),
#  ('Victaria Tyrell', 28.877333070519505),
#  ('Jyanna Frey', 28.84327199610689),
#  ('Nurse', 28.789102997202665),
#  ('Rolfe the Dwarf', 28.789102997202665),
#  ('Yurkhaz zo Yunzak', 28.789102997202665),
#  ('Eon Hunter', 28.784490377848947),
#  ('Alys Frey', 28.744610827056306),
#  ('Leo Lefford', 28.725341480165078),
#  ('Lyonel Frey', 28.708279912332856),
#  ('Wenda', 28.652315404349537),
#  ('Jhezane', 28.63944608324576),
#  ('Morna White Mask', 28.63944608324576),
#  ('Joanna Swyft', 28.612983084346123),
#  ('Tansy', 28.612983084346123),
#  ('Shierle Swyft', 28.593329060950122),
#  ('Arthur Dayne', 28.593312764597258),
#  ('Jon Arryn', 28.578881296848202),
#  ('Barra', 28.539556098314645),
#  ('Carellen Smallwood', 28.53441558636993),
#  ('Sharna', 28.53441558636993),
#  ('Three-Tooth', 28.372129057175766),
#  ('Boy', 28.34752318566174),
#  ('Pate (novice)', 28.340881480029644),
#  ('Betharios of Braavos', 28.312903837179082),
#  ('Galt', 28.284849659392442),
#  ('Hazrak zo Loraq', 28.21819096605902),
#  ('Mazdhan zo Loraq', 28.21819096605902),
#  ('Zharaq zo Loraq', 28.21819096605902),
#  ('Bellegere Otherys (courtesan)', 28.192632128891393),
#  ('Steelskin', 28.17921921706129),
#  ('Hobber Redwyne', 28.163750673605904),
#  ('Palla', 28.144365754489108),
#  ('Horas Redwyne', 28.14428356915255),
#  ('Marghaz zo Loraq', 28.08193307612843),
#  ('Elyn Norridge', 28.00749129692599),
#  ('Bandy', 27.991340238117914),
#  ('Shyra', 27.991340238117914),
#  ('Lysa Meadows', 27.988090119678933),
#  ('Dalbridge', 27.973439031559565),
#  ('Grazdan zo Galare', 27.95408995587745),
#  ('Lia Serry', 27.949312423856465),
#  ('Three Toes', 27.943752277587752),
#  ('Khorane Sathmantes', 27.923325553511404),
#  ('Lollys Stokeworth', 27.866982233494518),
#  ('Skahaz mo Kandaq', 27.85483225162675),
#  ('Urswyck', 27.846963869157438),
#  ('Leobald Tallhart', 27.802091687847586),
#  ('Lewyn Martell', 27.78863619656422),
#  ('Danwell Frey', 27.78542857632419),
#  ('Nail', 27.78263917371582),
#  ('Roone', 27.762997288612635),
#  ('Big Boil', 27.71645244914328),
#  ('Lomys', 27.634168150570616),
#  ('Ysilla', 27.628426803637083),
#  ('Amerei Frey', 27.625380647833076),
#  ('Bran Stark', 27.564108381062134),
#  ('Baelon Targaryen (son of Viserys I)', 27.535219627036366),
#  ('Denys Arryn', 27.530181641600837),
#  ('Xhondo', 27.51384587784491),
#  ('Rolder', 27.493355441603896),
#  ('Willamen Frey', 27.44730126962226),
#  ('Frynne', 27.42061796065419),
#  ('Roelle', 27.42061796065419),
#  ('Wat (orphan)', 27.401468585043),
#  ('Will (orphan)', 27.401468585043),
#  ('Elza', 27.38652589797691),
#  ('Bennet', 27.38232753720452),
#  ('Jon Penny', 27.38232753720452),
#  ('Wat (sailor)', 27.38232753720452),
#  ('Carrot', 27.363194820566207),
#  ('Dale Drumm', 27.363194820566207),
#  ('Ossy', 27.363194820566207),
#  ('Allard Seaworth', 27.351649603239913),
#  ('Maric Seaworth', 27.351649603239913),
#  ('Bloodbeard', 27.340709426372445),
#  ('Emphyria Vance', 27.324954394546296),
#  ('Liane Vance', 27.324954394546296),
#  ('Rhialta Vance', 27.324954394546296),
#  ('Terrance Lynderly', 27.324954394546296),
#  ('Umma', 27.324954394546296),
#  ('Dale Seaworth', 27.313419244766514),
#  ('Fralegg', 27.262450846143892),
#  ('Jasper Arryn', 27.2221721561555),
#  ('Kedge Whiteye', 27.21356705935658),
#  ('Aegon Targaryen (son of Rhaegar)', 27.203325632734764),
#  ('Rhonda Rowan', 27.134253287515243),
#  ('Pyg', 27.128278208472256),
#  ('Jeyne Fossoway', 27.11522918351369),
#  ('Rymolf', 26.97314916892394),
#  ('Zollo', 26.910276257198753),
#  ('Cleon', 26.8471107936874),
#  ('Egon Emeros', 26.750090848858587),
#  ('Borroq', 26.73233098275961),
#  ('Areo Hotah', 26.68635619509605),
#  ('Stonesnake', 26.65157827884267),
#  ('Howland Reed', 26.553953637523787),
#  ('Pia', 26.514402284975368),
#  ('Perriane Frey', 26.499133389595208),
#  ('Serala', 26.488070714897226),
#  ('Alesander Frey', 26.481465836826157),
#  ('Rolly Duckfield', 26.457796135147994),
#  ('Perros Blackmont', 26.429402992989548),
#  ('Luke of Longtown', 26.39770313831673),
#  ('Lucos Chyttering', 26.334510015286796),
#  ('Lucas Tyrell', 26.300861038415547),
#  ('Rickard Tyrell', 26.300861038415547),
#  ('Marillion', 26.29825926738375),
#  ('Raymund Tyrell', 26.282210481048097),
#  ('Hugh', 26.26081349370769),
#  ('Larraq', 26.25815434808998),
#  ('Luthor Tyrell (son of Theodore)', 26.226309894933564),
#  ('Thistle', 26.18055868203727),
#  ('Darlessa Marbrand', 26.15561373789903),
#  ('Spotted Cat', 26.09078176107672),
#  ('Owen Norrey', 26.05086298771151),
#  ('Squirrel', 26.032033432831938),
#  ('Wynafrei Whent', 26.02972947513853),
#  ('Aegon Targaryen', 26.020799469942936),
#  ('Howd Wanderer', 26.020799469942936),
#  ('Theomore Lannister', 26.020799469942936),
#  ('Myrtle', 26.013506220265313),
#  ('Gilwood Hunter', 26.011094532944202),
#  ('Walda Frey (daughter of Rhaegar)', 25.998674408861334),
#  ('Mors Manwoody', 25.995874664540853),
#  ('Willow Witch-eye', 25.99498755964731),
#  ('Dickon Manwoody', 25.97736414857801),
#  ('Kirth Vance', 25.97736414857801),
#  ('Jeyne Darry', 25.973932477909944),
#  ('Hosteen Frey', 25.914249748543305),
#  ('Smiling Knight', 25.903407682105662),
#  ('Belandra', 25.892873299681785),
#  ('Mero', 25.88899060319362),
#  ('Husband', 25.88493997790571),
#  ('Ned Woods', 25.88160313332335),
#  ('Mellei', 25.874410483285015),
#  ('Morra', 25.874410483285015),
#  ('Bodger', 25.858019925721585),
#  ('Lenn', 25.858019925721585),
#  ('Cedra', 25.855956238520548),
#  ('Steffon Frey', 25.84290512139271),
#  ('Oznak zo Pahl', 25.833633279258372),
#  ('Dyah', 25.802705768574285),
#  ('Ferny', 25.802705768574285),
#  ('Selwyn Tarth', 25.767490903971314),
#  ('Tygett Lannister', 25.763317482972113),
#  ('Beqqo', 25.7560849240007),
#  ('Lotho Lornel', 25.73768576926847),
#  ('Arthor Karstark', 25.73418264732187),
#  ('Canker Jeyne', 25.719295205011118),
#  ('Joss the Gloom', 25.719295205011118),
#  ('Moonshadow', 25.719295205011118),
#  ('Narbo', 25.719295205011118),
#  ('Poetess', 25.719295205011118),
#  ('Veiled Lady', 25.719295205011118),
#  ('Daughter of the Dusk', 25.700913233724688),
#  ('Roggo', 25.700913233724688),
#  ('Bethany (Blushing Bethany)', 25.682539857895005),
#  ('Sloey', 25.682539857895005),
#  ('Edric Dayne', 25.680636846327964),
#  ('Desmond', 25.679462544833232),
#  ('Quence', 25.664175079997552),
#  ('Talea', 25.664175079997552),
#  ('Brea', 25.645818902497563),
#  ('Kedry', 25.628578310314644),
#  ('Leo Tyrell', 25.600183647569807),
#  ('Kyra Frey', 25.591501840377717),
#  ('Bellegere Otherys', 25.55416710652384),
#  ('Duram Bar Emmon', 25.534248418959436),
#  ('Lyanna Stark', 25.52556636139802),
#  ('Timett (father)', 25.481422987399416),
#  ('Artos Stark', 25.371182793511394),
#  ('Joss Stilwood', 25.369276133772534),
#  ('Cheyk', 25.283429246872657),
#  ('Lewis Lanster', 25.250966390450845),
#  ('Jared Frey', 25.239189656706763),
#  ('Tybero Istarion', 25.214653140204945),
#  ('Moro', 25.177900232167293),
#  ('Ronald Storm', 25.069746629355826),
#  ('Rhaelle Targaryen', 25.0258078950124),
#  ('Gavin', 25.025326260211532),
#  ('Aemon Targaryen (son of Maekar I)', 25.011612415155128),
#  ('Briar', 25.007273299493825),
#  ('Grisella', 25.007273299493825),
#  ('Kyleg', 25.007273299493825),
#  ('Jarman Buckwell', 24.972109129043563),
#  ('Timeon', 24.946147538409125),
#  ('Quaro', 24.931355947447955),
#  ('Rat Cook', 24.899659369209903),
#  ('Aggar', 24.881730173255335),
#  ('Gelmarr', 24.881730173255335),
#  ('Gynir', 24.881730173255335),
#  ('Manfryd Lothston', 24.838616507503275),
#  ('Sylva Santagar', 24.836190396540715),
#  ('Mother Mole', 24.827221572506264),
#  ('Ygon Farwynd', 24.820653647214353),
#  ('Walder Frey (son of Jammos)', 24.794318008889714),
#  ('Eroeh', 24.784856269133915),
#  ('Alester Oakheart', 24.784754039677313),
#  ('Gyles Grafton', 24.784754039677313),
#  ('Yna', 24.766817296388023),
#  ('Robin Hollard', 24.73096994059003),
#  ('Skyte', 24.698755131283622),
#  ('Jaehaera Targaryen', 24.68433059529148),
#  ('Mollander', 24.677264263012177),
#  ('Harma', 24.671775025155174),
#  ('Melesa Crakehall', 24.667851456671187),
#  ('Tyana Wylde', 24.667851456671187),
#  ('Zhoe Blanetree', 24.667851456671187),
#  ('Jeyne Beesbury', 24.614238023454284),
#  ('Melara Crane', 24.57853936126243),
#  ('Jasper Waynwood', 24.570088379436417),
#  ('Timett', 24.565720248656277),
#  ('Rylene Florent', 24.560703123761495),
#  ('Leonella Lefford', 24.50724680780798),
#  ('Sallei Paege', 24.50724680780798),
#  ('Sylwa Paege', 24.50724680780798),
#  ('Denys Redwyne', 24.481015215907387),
#  ('Melessa Florent', 24.471652945906676),
#  ('Stalwart Shield', 24.469578217238265),
#  ('Deana Hardyng', 24.418327712265164),
#  ('Marsella Waynwood', 24.418327712265164),
#  ('Jeyne Lydden', 24.400570123973843),
#  ('Qarl Quickaxe', 24.394445931804242),
#  ('Farlen', 24.36805191319561),
#  ('Rhea Florent', 24.36508119235633),
#  ('Delena Florent', 24.31191343346475),
#  ('Wendel Manderly', 24.30638710264259),
#  ('Jate', 24.295255394388793),
#  ('Ezzelyno', 24.282253151721346),
#  ('Alyn', 24.279475428514264),
#  ('Helly', 24.267185370967436),
#  ('Jyzene', 24.267185370967436),
#  ('Alaric of Eysen', 24.2495024322505),
#  ('Cass', 24.2495024322505),
#  ('Bellena Hawick', 24.223475652369373),
#  ('Carolei Waynwood', 24.18816188188674),
#  ('Ryella Royce', 24.18816188188674),
#  ('Senelle', 24.185578723472567),
#  ('Rusty Flowers', 23.985454325939624),
#  ('Melly', 23.932155389880826),
#  ('Puddingfoot', 23.932155389880826),
#  ('Mariya Darry', 23.9244274217262),
#  ('Joanna Lannister', 23.919761266777286),
#  ('Walder Frey (son of Merrett)', 23.887355277845955),
#  ('Walda Frey (daughter of Merrett)', 23.867479967824366),
#  ('Wylis Manderly', 23.834194976478496),
#  ('Varamyr', 23.806870255399883),
#  ('Vickon Greyjoy', 23.717437588245915),
#  ('Quhuru Mo', 23.704806855338813),
#  ('Daryn Hornwood', 23.69728428772212),
#  ('Stafford Lannister', 23.66022636051266),
#  ('Big Walder Frey', 23.62822293203185),
#  ('Grunt', 23.61588681979676),
#  ('Wyman Manderly', 23.61514578105274),
#  ('Clydas', 23.577722968666535),
#  ('Frenya', 23.573040256098356),
#  ('Jorquen', 23.569907477751293),
#  ('Rowan', 23.486456199285367),
#  ('Bors', 23.442859115925984),
#  ('Timoth', 23.442859115925984),
#  ('Dan', 23.427522047245454),
#  ('Errok', 23.410261820984346),
#  ('Henk', 23.410261820984346),
#  ('Toefinger', 23.410261820984346),
#  ('Alyn Velaryon', 23.335149037107072),
#  ('Rhaenys Targaryen (daughter of Rhaegar)', 23.324835117648092),
#  ('Werlag', 23.283683902710706),
#  ('Cossomo', 23.263360740983252),
#  ('Gyleno Dothare', 23.263360740983252),
#  ('Gyloro Dothare', 23.263360740983252),
#  ('Orbelo', 23.263360740983252),
#  ('Terro', 23.263360740983252),
#  ('Garth Hightower', 23.25099751545614),
#  ('Quill', 23.24618474333011),
#  ('Gunthor Hightower', 23.233827882168868),
#  ('Allaquo', 23.229017588366197),
#  ('Yorko Terys', 23.211859277208756),
#  ('Harghaz', 23.205738438443603),
#  ('Becca', 23.185755769127315),
#  ('Tagganaro', 23.177569190735557),
#  ('Wendamyr', 23.177009185650775),
#  ('Alyssa Arryn', 23.168619769805865),
#  ('Ezzara', 23.16122887454214),
#  ('Melicent', 23.12855709521463),
#  ('Dhazzar', 23.126991056065492),
#  ('Maelor Targaryen', 23.121440647821835),
#  ('Quentin Tyrell', 23.11485385241382),
#  ('Tansy (orphan)', 23.111450650776955),
#  ('Azzak', 23.109885421694255),
#  ('Draqaz', 23.109885421694255),
#  ('Kezmya', 23.109885421694255),
#  ('Miklaz', 23.109885421694255),
#  ('Luthor Tyrell (son of Moryn)', 23.097754497863864),
#  ('Ashara Dayne', 23.077195710098376),
#  ('Nightingale', 23.06018442896197),
#  ('Ternesio Terys', 23.037153907776176),
#  ('Genna Lannister', 23.028959060100195),
#  ('Adrack Humble', 23.004416213073398),
#  ('Dagon Codd', 23.004416213073398),
#  ("Patrek of King's Mountain", 23.004416213073398),
#  ('Yezzan Zo Qaggaz', 23.004416213073398),
#  ('Simon Toyne', 22.977843472619153),
#  ('Ben Blackthumb', 22.944962291055603),
#  ('Ben Bones', 22.938137246146105),
#  ('Damon Dance-for-Me', 22.938137246146105),
#  ('Skinner', 22.938137246146105),
#  ('Sour Alyn', 22.88714103422549),
#  ('Lady of the Leaves', 22.869299843523947),
#  ('Steffon Stackspear', 22.869299843523947),
#  ('Ryman Frey', 22.83163007913407),
#  ('Mudge (brotherhood)', 22.770646606738698),
#  ...]

# %%
#Los modelos finalmente elkegidos fueron
#inner_reglog
#left_balanced
#left_balanced_cht
#left_svm_rbf_cht
#left_forest_cht
pred_df = pd.DataFrame(predict_s8('inner_reglog'))
pred_df
# Out:
#                                               0          1
# 0                              Tyrion Lannister  98.832486
# 1                                      Jon Snow  98.240118
# 2                                   Sansa Stark  92.236378
# 3                                 Theon Greyjoy  92.094012
# 4                                    Arya Stark  91.489965
# 5                            Daenerys Targaryen  90.631987
# 6                                     Missandei  89.736849
# 7                                Sandor Clegane  86.420415
# 8                               Jaime Lannister  84.797969
# 9                              Cersei Lannister  81.639477
# 10                                Jorah Mormont  81.380670
# 11                             Brienne of Tarth  81.015054
# 12                                Samwell Tarly  80.102250
# 13                                   Melisandre  78.477978
# 14                                        Gilly  76.718611
# 15                                        Varys  76.235534
# 16                               Davos Seaworth  75.841433
# 17                                       Gendry  75.006485
# 18                                Brandon Stark  71.758817
# 19                                 Robert Arryn  71.339539
# 20                                   Meera Reed  68.757508
# 21                              Alysane Mormont  67.972172
# 22                                    Grey Worm  64.935631
# 23                              Illyrio Mopatis  64.873652
# 24                               Daario Naharis  64.585930
# 25                                      Monster  64.051274
# 26                                Podrick Payne  63.141110
# 27                              Janei Lannister  60.515610
# 28                                  Loreza Sand  60.423676
# 29                                 Ysilla Royce  59.948635
# ...                                         ...        ...
# 1905                            Baela Targaryen   4.221570
# 1906                           Ardrian Celtigar   3.995825
# 1907                           Pate (Standfast)   3.953383
# 1908                            Lem (Standfast)   3.836429
# 1909                            Saera Targaryen   3.778241
# 1910    Daella Targaryen (daughter of Maekar I)   3.767759
# 1911      Rhaena Targaryen (daughter of Daemon)   3.664928
# 1912                                 Jon Waters   3.633560
# 1913                          Helicent Uffering   3.487666
# 1914                             Jeyne Lothston   3.487666
# 1915                                    Nettles   3.449000
# 1916                         Baelor I Targaryen   3.389990
# 1917                             Lyman Beesbury   3.260286
# 1918                           Elaena Targaryen   3.111507
# 1919                         Ambrose Butterwell   2.856734
# 1920                        Daeron II Targaryen   2.676946
# 1921                         Aerys II Targaryen   2.506917
# 1922                             Rohanne Webber   2.496017
# 1923                               Jeyne Waters   2.462013
# 1924                       Viserys II Targaryen   2.378477
# 1925                                Gawen Swann   2.291339
# 1926                          Falena Stokeworth   2.287034
# 1927                            Joffrey Caswell   2.287034
# 1928                               Larys Strong   2.117159
# 1929                         Aegon IV Targaryen   1.889870
# 1930                            Uthor Underleaf   1.817803
# 1931                            Glendon Flowers   1.802409
# 1932  Daenerys Targaryen (daughter of Aegon IV)   1.775182
# 1933                            Daena Targaryen   1.555087
# 1934                           Naerys Targaryen   0.726611
#
# [1935 rows x 2 columns]

# %%
pred_df[pred_df[0]=='Lyanna Mormont']
# Out:
#                    0          1
# 1397  Lyanna Mormont  88.303333

# %%
pred_df[pred_df[0]=='Euron Greyjoy']
# Out:
#                   0          1
# 1245  Euron Greyjoy  89.107513

# %% [markdown]
# > Will work with predictions from Best Logistic Regression Model using LEFT JOIN data.
# > To import it from other applications, including the [Flask App](06_GOT_app) load it from file [../models/left_reglog.pkl](../models/left_reglog.pkl) using **pickle**
#
# > Run app via command prompt:
# ```bash
# python3 06_GOT_app.py
# ```
# > and go to http://127.0.0.1:5000/predict
